# %% [markdown]
# **Pros and Cons of Linked List**
#
# **_Advantages_**
#
# _Dynamic Data Structure_
#
# _Insertion and Deletion_
#
# _No Memory Wastage_
#
# _Implementation_
#
#
# **_Disadvantages_**
#
# _Extra Memory Usage : Each note contins a pointer and it requires in a extra memory_
#
# _Traversal : Full node access requires_
#
# _Revere Traversing : Double linked list_
#
# _Random Access : This is not possible_

# %% [markdown]
# ## Structure of a Linked List

# %%
class Node:
    def __init__(self,data):
        self.data=data       #Assign Data
        selt.next=None       #Inıtialize next as null

# %%
class LinkedList:
    #Function to initialize the Linked List object
    def __init__(self):
        self.head=None

# %% [markdown]
# # Types of Linked List

# %% [markdown]
# _**Singly Linked List**_
#
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# _**Doubly Linked List**_
#
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# _**Circular Linked List**_
#
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
#
# _**Double Circular Linked List**_
#
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)
